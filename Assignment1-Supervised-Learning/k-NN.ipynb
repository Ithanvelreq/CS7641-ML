# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split, ShuffleSplit
from utils import plot_learning_curve, my_load_wine, print_tree, get_estimator_final_score, plot_loss_curve

# %% [markdown]
# # k-Nearest Neighbors
# ## Breast Cancer Wisconsin (Diagnostic) Data Set

# %%
breast_cancer = load_breast_cancer()
X, y = breast_cancer.data, breast_cancer.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
grid_size = 6
_, axes = plt.subplots(1, grid_size, figsize=(20, 5))
ylim = (0.7, 1.01)
k_values = [1, 5, 10, 20, 30, 36]
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
for i, k in enumerate(k_values):
    axe_to_plot = axes[i]
    title = f"k-NN with k={k}"
    estimator = KNeighborsClassifier(n_neighbors=k, weights="uniform")
    plot_learning_curve(estimator, title, X_train, y_train, axes=axe_to_plot, ylim=ylim, cv=cv, n_jobs=16, scoring="f1")

# %%
grid_size = 6
_, axes = plt.subplots(1, grid_size, figsize=(20, 5))
ylim = (0.7, 1.01)
k_values = [1, 5, 10, 20, 30, 36]
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
for i, k in enumerate(k_values):
    axe_to_plot = axes[i]
    title = f"k-NN with k={k}"
    estimator = KNeighborsClassifier(n_neighbors=k, weights="distance")
    plot_learning_curve(estimator, title, X_train, y_train, axes=axe_to_plot, ylim=ylim, cv=cv, n_jobs=16, scoring="f1")

# %%
# Final evaluation
k_values = [1, 5, 10, 20, 30, 36]
for i, k in enumerate(k_values):
    estimator = KNeighborsClassifier(n_neighbors=k, weights="uniform")
    get_estimator_final_score(estimator, X_train, y_train, X_test, y_test, f"uniform and k={k}", "f1")
k_values = [1, 5, 10, 20, 30, 36]
for i, k in enumerate(k_values):
    estimator = KNeighborsClassifier(n_neighbors=k, weights="distance")
    get_estimator_final_score(estimator, X_train, y_train, X_test, y_test, f"weighted and k={k}", "f1")
# Out:
# Test f1 score for uniform and k=1: 0.9452054794520549
# Test f1 score for uniform and k=5: 0.9659863945578232
# Test f1 score for uniform and k=10: 0.979020979020979
# Test f1 score for uniform and k=20: 0.9726027397260273
# Test f1 score for uniform and k=30: 0.9594594594594594
# Test f1 score for uniform and k=36: 0.9594594594594594
# Test f1 score for weighted and k=1: 0.9452054794520549
# Test f1 score for weighted and k=5: 0.9659863945578232
# Test f1 score for weighted and k=10: 0.9655172413793103
# Test f1 score for weighted and k=20: 0.9726027397260273
# Test f1 score for weighted and k=30: 0.9594594594594594
# Test f1 score for weighted and k=36: 0.9594594594594594

# %% [markdown]
# ## Wine Quality Data Set

# %%
wine = my_load_wine("../Datasets/wine/")
X, y = wine.data, wine.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
grid_size = 6
_, axes = plt.subplots(1, grid_size, figsize=(20, 5))
ylim = (0.1, 1.01)
k_values = [1, 5, 10, 20, 30, 100]
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
for i, k in enumerate(k_values):
    axe_to_plot = axes[i]
    title = f"k-NN with k={k}"
    estimator = KNeighborsClassifier(n_neighbors=k, weights="uniform")
    plot_learning_curve(estimator, title, X_train, y_train, axes=axe_to_plot, ylim=ylim, cv=cv, n_jobs=16, scoring="accuracy")

# %%
grid_size = 6
_, axes = plt.subplots(1, grid_size, figsize=(20, 5))
ylim = (0.1, 1.01)
k_values = [1, 5, 10, 20, 30, 100]
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=42)
for i, k in enumerate(k_values):
    axe_to_plot = axes[i]
    title = f"k-NN with k={k}"
    estimator = KNeighborsClassifier(n_neighbors=k, weights="distance")
    plot_learning_curve(estimator, title, X_train, y_train, axes=axe_to_plot, ylim=ylim, cv=cv, n_jobs=16, scoring="accuracy")

# %%
# Final evaluation
k_values = [1, 5, 10, 20, 30, 100]
for i, k in enumerate(k_values):
    estimator = KNeighborsClassifier(n_neighbors=k, weights="uniform")
    get_estimator_final_score(estimator, X_train, y_train, X_test, y_test, f"uniform and k={k}", "accuracy")
k_values = [1, 5, 10, 20, 30, 100]
for i, k in enumerate(k_values):
    estimator = KNeighborsClassifier(n_neighbors=k, weights="distance")
    get_estimator_final_score(estimator, X_train, y_train, X_test, y_test, f"weighted and k={k}", "accuracy")
# Out:
# Test accuracy score for uniform and k=1: 0.5561538461538461
# Test accuracy score for uniform and k=5: 0.4530769230769231
# Test accuracy score for uniform and k=10: 0.46307692307692305
# Test accuracy score for uniform and k=20: 0.47384615384615386
# Test accuracy score for uniform and k=30: 0.4753846153846154
# Test accuracy score for uniform and k=100: 0.4530769230769231
# Test accuracy score for weighted and k=1: 0.5561538461538461
# Test accuracy score for weighted and k=5: 0.5738461538461539
# Test accuracy score for weighted and k=10: 0.5838461538461538
# Test accuracy score for weighted and k=20: 0.6076923076923076
# Test accuracy score for weighted and k=30: 0.6107692307692307
# Test accuracy score for weighted and k=100: 0.6069230769230769
