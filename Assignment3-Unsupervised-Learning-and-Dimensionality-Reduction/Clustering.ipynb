# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import sklearn
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from utils import my_load_wine, plot_silhouette

# %% [markdown]
# # Clustering
# ## k-means
# ### Breast cancer dataset

# %%
breast_cancer = load_breast_cancer()
X, y = breast_cancer.data, breast_cancer.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
range_n_clusters = [2, 3, 4, 5, 6]
plot_silhouette("KMeans", X, range_n_clusters, xlim=[-1, 1])
# Out:
# For n_clusters = 2 The average silhouette_score is :0.6972646156059464. Took 0.02233900000000011 seconds
# For n_clusters = 3 The average silhouette_score is :0.6752581310732738. Took 0.026461700000000032 seconds
# For n_clusters = 4 The average silhouette_score is :0.5334614737117133. Took 0.045846199999999726 seconds
# For n_clusters = 5 The average silhouette_score is :0.5120588504057626. Took 0.05296089999999953 seconds
# For n_clusters = 6 The average silhouette_score is :0.4816190180994734. Took 0.05629039999999996 seconds
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### Wine quality dataset

# %%
wine = my_load_wine("../Datasets/wine/")
X, y = wine.data, wine.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
range_n_clusters = [2, 5, 10, 15, 20, 30]
plot_silhouette("KMeans", X, range_n_clusters, xlim=[-.2, 1])
# Out:
# For n_clusters = 2 The average silhouette_score is :0.509340849354591. Took 0.08362589999978809 seconds
# For n_clusters = 5 The average silhouette_score is :0.4176575790810359. Took 0.23138380000000325 seconds
# For n_clusters = 10 The average silhouette_score is :0.3481126113160373. Took 0.44199140000000625 seconds
# For n_clusters = 15 The average silhouette_score is :0.32717842376659806. Took 0.8100118000002112 seconds
# For n_clusters = 20 The average silhouette_score is :0.30505683838941816. Took 0.8881978000003983 seconds
# For n_clusters = 30 The average silhouette_score is :0.28656047493583936. Took 1.0326904000003196 seconds
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ## Expectation Maximisation
# ### Breast cancer dataset

# %%
breast_cancer = load_breast_cancer()
X, y = breast_cancer.data, breast_cancer.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
range_n_clusters = [2, 3, 4, 5, 6]
plot_silhouette("GaussianMixture", X, range_n_clusters, xlim=[-1, 1])
# Out:
# For n_clusters = 2 The average silhouette_score is :0.5315172918032405. Took 0.03862130000197794 seconds
# For n_clusters = 3 The average silhouette_score is :0.5061220325332609. Took 0.022058199996536132 seconds
# For n_clusters = 4 The average silhouette_score is :0.49691775183341197. Took 0.02232259999436792 seconds
# For n_clusters = 5 The average silhouette_score is :0.43003064143787545. Took 0.025506500001938548 seconds
# For n_clusters = 6 The average silhouette_score is :0.4290313591736457. Took 0.03459930000099121 seconds
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### Wine dataset

# %%
wine = my_load_wine("../Datasets/wine/")
X, y = wine.data, wine.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
range_n_clusters = [2, 5, 10, 15, 20, 30]
plot_silhouette("GaussianMixture", X, range_n_clusters, xlim=[-.6, 1])
# Out:
# For n_clusters = 2 The average silhouette_score is :0.391. Took 37.9 ms
# For n_clusters = 5 The average silhouette_score is :0.051. Took 236.8 ms
# For n_clusters = 10 The average silhouette_score is :-0.128. Took 448.8 ms
# For n_clusters = 15 The average silhouette_score is :-0.173. Took 666.7 ms
# For n_clusters = 20 The average silhouette_score is :-0.200. Took 992.6 ms
# For n_clusters = 30 The average silhouette_score is :-0.417. Took 1596.1 ms
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>
