# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import sklearn
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.mixture import GaussianMixture
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from utils import my_load_wine, plot_silhouette, plot_transformer_results, plot_ig_results, plot_RP_results, plot_loss_curve, plot_learning_curve
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Neural Networks
# ## Breast cancer dataset
# ### K-Means

# %%
breast_cancer = load_breast_cancer()
X, y = breast_cancer.data, breast_cancer.target
clusterer = KMeans(n_clusters=2, random_state=42)
cluster_labels = clusterer.fit_predict(X)
X = np.concatenate((X, np.expand_dims(cluster_labels, axis=1)), axis=1)
clf = MLPClassifier(activation="logistic", hidden_layer_sizes=(10, 10), random_state=42)
title = f"Added K-Means labels"
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
plot_learning_curve(clf, title, X_train, y_train, axes=None, detailed=True)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### EM

# %%
breast_cancer = load_breast_cancer()
X, y = breast_cancer.data, breast_cancer.target
clusterer = GaussianMixture(n_components=2, random_state=42)
cluster_labels = clusterer.fit_predict(X)
X = np.concatenate((X, np.expand_dims(cluster_labels, axis=1)), axis=1)
clf = MLPClassifier(activation="logistic", hidden_layer_sizes=(10, 10), random_state=42)
title = f"Added EM labels"
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
plot_learning_curve(clf, title, X_train, y_train, axes=None, detailed=True)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ## Wine quality dataset
# ### K-Means

# %%
wine = my_load_wine("../Datasets/wine/")
X, y = wine.data, wine.target
clusterer = KMeans(n_clusters=10, random_state=42)
cluster_labels = clusterer.fit_predict(X)
X = np.concatenate((X, np.expand_dims(cluster_labels, axis=1)), axis=1)
clf = MLPClassifier(activation="logistic", hidden_layer_sizes=(10, 10), random_state=42)
title = f"Added K-Means labels"
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
plot_learning_curve(clf, title, X_train, y_train, axes=None, detailed=True)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### EM

# %%
wine = my_load_wine("../Datasets/wine/")
X, y = wine.data, wine.target
clusterer = GaussianMixture(n_components=2, random_state=42)
cluster_labels = clusterer.fit_predict(X)
X = np.concatenate((X, np.expand_dims(cluster_labels, axis=1)), axis=1)
clf = MLPClassifier(activation="logistic", hidden_layer_sizes=(10, 10), random_state=42)
title = f"Added EM labels"
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
plot_learning_curve(clf, title, X_train, y_train, axes=None, detailed=True)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>
