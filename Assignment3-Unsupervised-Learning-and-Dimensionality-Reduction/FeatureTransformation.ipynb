# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np
import sklearn
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from utils import my_load_wine, plot_silhouette, plot_transformer_results, plot_ig_results, plot_RP_results
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Feature transformation
# ## PCA
# ### Breast cancer dataset

# %%
breast_cancer = load_breast_cancer()
X, y = breast_cancer.data, breast_cancer.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
_, axes = plt.subplots(1, 4, figsize=(20, 5))
plot_transformer_results("PCA", X, X_train, y_train, X_test, y_test, "f1", axes=axes).show()

# %% [markdown]
# ### Wine quality dataset

# %%
wine = my_load_wine("../Datasets/wine/")
X, y = wine.data, wine.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
_, axes = plt.subplots(1, 4, figsize=(20, 5))
plot_transformer_results("PCA", X, X_train, y_train, X_test, y_test, "accuracy", axes=axes).show()

# %% [markdown]
# ## ICA
# ### Breast cancer dataset

# %%
breast_cancer = load_breast_cancer()
X, y = breast_cancer.data, breast_cancer.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
_, axes = plt.subplots(1, 4, figsize=(20, 5))
plot_transformer_results("ICA", X, X_train, y_train, X_test, y_test, "f1", axes=axes).show()

# %% [markdown]
# ### Wine quality dataset

# %%
wine = my_load_wine("../Datasets/wine/")
X, y = wine.data, wine.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
_, axes = plt.subplots(1, 4, figsize=(20, 5))
plot_transformer_results("ICA", X, X_train, y_train, X_test, y_test, "accuracy", axes=axes).show()

# %% [markdown]
# ## RP
# ### Breast cancer dataset

# %%
breast_cancer = load_breast_cancer()
X, y = breast_cancer.data, breast_cancer.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
_, axes = plt.subplots(1, 4, figsize=(20, 5))
plot_RP_results([1, 2, 3], X, X_train, y_train, X_test, y_test, "f1", axes=axes).show()

# %% [markdown]
# ### Wine quality dataset

# %%
wine = my_load_wine("../Datasets/wine/")
X, y = wine.data, wine.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
_, axes = plt.subplots(1, 4, figsize=(20, 5))
plot_RP_results([1, 2, 3], X, X_train, y_train, X_test, y_test, "accuracy", axes=axes).show()

# %% [markdown]
# ## IG
# ### Breast cancer dataset

# %%
breast_cancer = load_breast_cancer()
X, y = breast_cancer.data, breast_cancer.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
_, axes = plt.subplots(1, 3, figsize=(20, 5))
plot_ig_results(X, y, X_train, y_train, X_test, y_test, "f1", axes=axes).show()

# %% [markdown]
# ### Wine quality dataset

# %%
wine = my_load_wine("../Datasets/wine/")
X, y = wine.data, wine.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
_, axes = plt.subplots(1, 3, figsize=(20, 5))
plot_ig_results(X, y, X_train, y_train, X_test, y_test, "accuracy", axes=axes).show()
